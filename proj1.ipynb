# %%
import pandas as pd
#"What is the impact of [independent variable] on [dependent variable] in the context of [specific population or domain]?"
#How does the emotion of fear (FEAR) influence gun ownership (own_gun) among women (sex)?
var_list = ['fear', 'owngun', 'sex', 'hunt']# List of variables to save
output_file = 'raw_gss_data_ytkidanu.csv' # Name of the file to save the data to
#
modes = ['w','a'] # Has write mode and append mode
phase = 0 # Starts in write mode; after one iteration of loop, switches to append mode
#
for k in range(37): # r each chunk of the data
    url = 'https://github.com/DS3001/gss_zip/raw/main/gss_' + str(1+k) + '.csv' # Create url to the chunk to be processed
    print(url) # Check the url is correct
    df = pd.read_csv(url,low_memory=False) # Download this chunk of data
    print(df.head()) # Visually inspect the first few rows
    df.loc[:,var_list].to_csv(output_file, # specifies target file to save the chunk to
                              mode=modes[phase], # control write versus append
                              header=var_list, # variable names
                              index=False) # no row index saved
    phase = 1 # Switch from write mode to append mode
    k =+ 1
# Out:
# https://github.com/DS3001/gss_zip/raw/main/gss_1.csv
#    Unnamed: 0  year  id            wrkstat  hrs1  hrs2 evwork    occ  \
# 0           1  1972   1  working full time   NaN   NaN    NaN  205.0
# 1           2  1972   2            retired   NaN   NaN    yes  441.0
# 2           3  1972   3  working part time   NaN   NaN    NaN  270.0
# 3           4  1972   4  working full time   NaN   NaN    NaN    1.0
# 4           5  1972   5      keeping house   NaN   NaN    yes  385.0
#
#    prestige        wrkslf  ...  instype02  instype03  instype04  \
# 0      50.0  someone else  ...        NaN        NaN        NaN
# 1      45.0  someone else  ...        NaN        NaN        NaN
# 2      44.0  someone else  ...        NaN        NaN        NaN
# 3      57.0  someone else  ...        NaN        NaN        NaN
# 4      40.0  someone else  ...        NaN        NaN        NaN
#
#    totalincentive  wtssps_nea  wtssnrps_nea  wtssps_next  wtssnrps_next  \
# ...

# %%
# Check list of the unique values occuring for "fear" variable
unique_fear= df['fear'].unique() #['no' 'yes' nan]
print(unique_fear)
print(df['fear'].value_counts())
missing_values = df['fear'].isnull().sum() #check missing values
print("Number of missing values ", missing_values) #132,

#df[var].fillna('Unknown', inplace=True)
#df['Type_Missing']=df['fear'].replace(np.nan,  0)
# Out:
# ['no' 'yes' nan]
# no     184
# yes     74
# Name: fear, dtype: int64
# Number of missing values  132

# %%
import numpy as np 
df['fear_no_na']=df['fear'].replace(np.nan, 'Unknown')
df['fear'] = df['fear'].replace(np.nan, 'Unknown')  # update the 'fear' column
#print(df['fear'].value_counts())
unique_fear= df['fear'].unique()
print(df['fear_no_na'])
print(df['fear_no_na'].value_counts())
# Out:
# 0           no
# 1          yes
# 2          yes
# 3          yes
# 4          yes
#         ...
# 385         no
# 386        yes
# 387    Unknown
# 388         no
# 389    Unknown
# Name: fear_no_na, Length: 390, dtype: object
# no         184
# Unknown    132
# yes         74
# Name: fear_no_na, dtype: int64

# %%
unique_sex= df['sex'].unique() #
print(unique_sex)
print(df['sex'].value_counts())
missing_values_sex = df['sex'].isnull().sum() #check missing values
print("Number of missing values ", missing_values_sex) # already clean

#df[var].fillna('Unknown', inplace=True)
#df['Type_Missing']=df['fear'].replace(np.nan,  0)
# Out:
# ['male' 'female']
# female    206
# male      184
# Name: sex, dtype: int64
# Number of missing values  0

# %%
unique_owngun= df['owngun'].unique() #
print(unique_owngun)
print(df['owngun'].value_counts())
missing_values_gun = df['owngun'].isnull().sum() #check missing values
print("Number of missing values ", missing_values_gun) # already clean
# Out:
# ['yes' 'no' nan 'refused_(3)']
# yes            141
# no             111
# refused_(3)      7
# Name: owngun, dtype: int64
# Number of missing values  131

# %%
df['owngun'] = df['owngun'].replace('refused_(3)', np.nan) # replace the refused with nan
df['owngun_no_na']=df['owngun'].replace(np.nan, 'Unknown')
df['owngun'] = df['owngun'].replace(np.nan, 'Unknown')  # update the 'owngun' column
#print(df['fear'].value_counts())
unique_fear= df['owngun'].unique()
print(df['owngun_no_na'])

print(df['owngun_no_na'].value_counts()) # when doing eda portion, use the owngun_no_na
# Out:
# 0          yes
# 1          yes
# 2           no
# 3           no
# 4          yes
#         ...
# 385        yes
# 386        yes
# 387    Unknown
# 388         no
# 389    Unknown
# Name: owngun_no_na, Length: 390, dtype: object
# yes        141
# Unknown    138
# no         111
# Name: owngun_no_na, dtype: int64

# %%
unique_sex= df['hunt'].unique() #
print(unique_sex) # get rid of ye
# Out:
# ['yes, respondent does' 'no, neither r nor spouse hunts' 'yes, both do'
#  nan 'yes, spouse does']

# %%
no_hunt_df = df[df['hunt'] == 'no, neither r nor spouse hunts'] # keeps only those that don’t hunt
women_data = no_hunt_df[no_hunt_df['sex'] == 'female'] # got rid of anyone not female

print(women_data.head())

# women data = data frame we are going to use
# fear_ni_na
#sex
# owngun_na
# Out:
#     Unnamed: 0  year    id                                 wrkstat  hrs1  \
# 1        72002  2022  3156                                   other   NaN
# 2        72003  2022  3157  unemployed, laid off, looking for work   NaN
# 4        72005  2022  3159                           keeping house   NaN
# 8        72009  2022  3163                       working full time  60.0
# 12       72013  2022  3167                                   other   NaN
#
#     hrs2 evwork  occ  prestige         wrkslf  ...  instype04  totalincentive  \
# 1    NaN    yes  NaN       NaN   someone else  ...        NaN              84
# 2    NaN    NaN  NaN       NaN  self-employed  ...        NaN              87
# 4    NaN    yes  NaN       NaN   someone else  ...        NaN             167
# 8    NaN    NaN  NaN       NaN   someone else  ...        NaN             137
# 12   NaN    yes  NaN       NaN   someone else  ...        NaN             137
#
# ...
